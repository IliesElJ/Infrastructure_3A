# %%
import pandas as pd
import numpy as np

df= pd.read_excel("financial_summary_tesla.xlsx", )
df.head()
# Out:
#         Period  Automotive revenue  Automotive revenue YoY  Total Revenues  \
# 0   2022-01-03               16861                    0.87           18756
# 1   2022-01-04               16861                    0.87           18756
# 2   2022-01-05               16861                    0.87           18756
# 3   2022-01-06               16861                    0.87           18756
# 4   2022-01-07               16861                    0.87           18756
# ..         ...                 ...                     ...             ...
# 361 2022-12-30               21307                    0.33           24318
# 362 2022-12-31               21307                    0.33           24318
# 363 2023-01-01               19963                    0.18           23329
# 364 2023-01-02               19963                    0.18           23329
# 365 2023-01-03               19963                    0.18           23329
#
# ...
