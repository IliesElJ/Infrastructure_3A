# %%
import pandas as pd
import numpy as np

df= pd.read_excel("financial_summary_tesla.xlsx", index_col = 'Period')
df.head()
# Out:
#             Automotive revenue  Automotive revenue YoY  Total Revenues  \
# Period
# 2022-01-03               16861                    0.87           18756
# 2022-01-04               16861                    0.87           18756
# 2022-01-05               16861                    0.87           18756
# 2022-01-06               16861                    0.87           18756
# 2022-01-07               16861                    0.87           18756
#
#             Total Revenues YoY  Total Gross Profit  Total Gross Profit YoY  \
# Period
# 2022-01-03                0.81                5460                    1.47
# 2022-01-04                0.81                5460                    1.47
# 2022-01-05                0.81                5460                    1.47
# 2022-01-06                0.81                5460                    1.47
# 2022-01-07                0.81                5460                    1.47
#
# ...
