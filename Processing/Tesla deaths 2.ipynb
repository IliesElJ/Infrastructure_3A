# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_excel("../Datasets/Tesla Deaths.xlsx")

# %%
df
# Out:
#     Tesla Deaths Unnamed: 1           Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0         Case #       Year                 Date    Country      State
# 1            377       2023  2023-11-15 00:00:00        USA         NC
# 2            376       2023  2023-11-04 00:00:00        USA         WA
# 3            375       2023  2023-11-03 00:00:00        USA         FL
# 4            374       2023  2023-10-30 00:00:00        USA         NY
# ..           ...        ...                  ...        ...        ...
# 398          NaN        NaN                  NaN        NaN        NaN
# 399          NaN        NaN                  NaN        NaN        NaN
# 400          NaN        NaN                  NaN        NaN        NaN
# 401          NaN        NaN                  NaN        NaN        NaN
# 402          NaN        NaN                  NaN        NaN        NaN
#
#                                 Unnamed: 5 Unnamed: 6    Unnamed: 7  \
# ...

# %%
df.iloc[:,:10]
# Out:
#     Tesla Deaths Unnamed: 1           Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0         Case #       Year                 Date    Country      State
# 1            377       2023  2023-11-15 00:00:00        USA         NC
# 2            376       2023  2023-11-04 00:00:00        USA         WA
# 3            375       2023  2023-11-03 00:00:00        USA         FL
# 4            374       2023  2023-10-30 00:00:00        USA         NY
# ..           ...        ...                  ...        ...        ...
# 398          NaN        NaN                  NaN        NaN        NaN
# 399          NaN        NaN                  NaN        NaN        NaN
# 400          NaN        NaN                  NaN        NaN        NaN
# 401          NaN        NaN                  NaN        NaN        NaN
# 402          NaN        NaN                  NaN        NaN        NaN
#
#                                 Unnamed: 5 Unnamed: 6    Unnamed: 7  \
# ...

# %%
df.iloc[:189,2]
# Out:
# 0                     Date
# 1      2023-11-15 00:00:00
# 2      2023-11-04 00:00:00
# 3      2023-11-03 00:00:00
# 4      2023-10-30 00:00:00
#               ...
# 184    2022-02-12 00:00:00
# 185    2022-02-07 00:00:00
# 186    2022-01-16 00:00:00
# 187    2022-01-01 00:00:00
# 188    2022-01-01 00:00:00
# Name: Unnamed: 2, Length: 189, dtype: object

# %%
df = df.iloc[:189,:10]

# %%
df
# Out:
#     Tesla Deaths Unnamed: 1           Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0         Case #       Year                 Date    Country      State
# 1            377       2023  2023-11-15 00:00:00        USA         NC
# 2            376       2023  2023-11-04 00:00:00        USA         WA
# 3            375       2023  2023-11-03 00:00:00        USA         FL
# 4            374       2023  2023-10-30 00:00:00        USA         NY
# ..           ...        ...                  ...        ...        ...
# 184          204       2022  2022-02-12 00:00:00        USA         CA
# 185          203       2022  2022-02-07 00:00:00        USA         FL
# 186          202       2022  2022-01-16 00:00:00        USA         CA
# 187          201       2022  2022-01-01 00:00:00        USA         CA
# 188          200       2022  2022-01-01 00:00:00        USA         CA
#
#                                   Unnamed: 5 Unnamed: 6    Unnamed: 7  \
# ...
