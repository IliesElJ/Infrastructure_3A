# %%
import pandas as pd

# %%
df = pd.read_csv("../Datasets/Elon musk tweets 2022.csv")

# %%
df
# Out:
#                            date  \
# 0     2022-12-30 23:25:29+00:00
# 1     2022-12-30 23:16:58+00:00
# 2     2022-12-30 22:51:35+00:00
# 3     2022-12-30 22:43:10+00:00
# 4     2022-12-30 22:28:13+00:00
# ...                         ...
# 5028  2022-01-02 22:56:00+00:00
# 5029  2022-01-02 18:19:33+00:00
# 5030  2022-01-02 17:56:50+00:00
# 5031  2022-01-01 01:58:52+00:00
# 5032  2022-01-01 00:53:13+00:00
#
#                                                 Content   Likes  Retweet
# 0                                           @BillyM2k 🦜    6453      359
# 1                                       @getpaidwrite 💯   18650      546
# 2     @teslaownersSV It’s good to switch back &amp; ...    6618      475
# 3     @teslaownersSV @Tesla Long-term fundamentals a...   22549     1942
# 4     @Rainmaker1973 @paulg Sorry, this incorrect ta...    8813      325
# ...                                                 ...     ...      ...
# ...
