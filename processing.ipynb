# %%
pip install yfinance
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 4.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 21.4 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 14.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 kB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 23.1 MB/s eta 0:00:0000:0100:01
# ...
#   Created wheel for peewee: filename=peewee-3.17.0-cp310-cp310-linux_x86_64.whl size=272556 sha256=15bdd1d06af313000f1af0536cbf4b8a263201e5f2c1259d682dad0813a63ca2
#   Stored in directory: /home/onyxia/.cache/pip/wheels/c7/70/ad/212867e96e7004265a69c4aa5dcff00a95f547a67ba26e7e76
# Successfully built peewee
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf

# %%
symbol = "AAPL"
start_date = "2022-01-01"
end_date = "2022-12-31"

# Utilisez la fonction `download` pour collecter les données
data = yf.download(symbol, start=start_date, end=end_date)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-01-03  177.830002  182.880005  177.710007  182.009995  179.953903
# 2022-01-04  182.630005  182.940002  179.119995  179.699997  177.669983
# 2022-01-05  179.610001  180.169998  174.639999  174.919998  172.943985
# 2022-01-06  172.699997  175.300003  171.639999  172.000000  170.056992
# 2022-01-07  172.889999  174.139999  171.029999  172.169998  170.225052
# ...                ...         ...         ...         ...         ...
# 2022-12-23  130.919998  132.419998  129.639999  131.860001  131.127060
# 2022-12-27  131.380005  131.410004  128.720001  130.029999  129.307236
# 2022-12-28  129.669998  131.029999  125.870003  126.040001  125.339409
# 2022-12-29  127.989998  130.479996  127.730003  129.610001  128.889572
# 2022-12-30  128.410004  129.949997  127.430000  129.929993  129.207794
#
#                Volume
# Date
# 2022-01-03  104487900
# 2022-01-04   99310400
# 2022-01-05   94537600
# ...
